# %%
from py2neo import Graph
import pandas as pd

from utilities import neo4j_utilities

# %%
from tqdm.notebook import tqdm
from tqdm import tqdm as progress_tqdm
tqdm.pandas()

# %%
api_key = "..."

# %%
# Connect to the Neo4j database
graph = Graph("bolt://localhost:7687", name = "smallstc", auth=("neo4j", "Stargate90"))

# %%
query = """
MATCH (a:doi)
RETURN a.title as title, a.abstract as abstract, a.languages AS languages, a.type AS type, a.tags as tags, a.name as doi
"""

# %%
# Execute the query
data = graph.run(query).data()

# %%
# Convert the result to a DataFrame
df = pd.DataFrame(data)

# %%
df_clean_articles = df.dropna(subset=['title'])

# %%
df_clean_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20666 entries, 0 to 372181
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      20666 non-null  object
#  1   abstract   6603 non-null   object
#  2   languages  20072 non-null  object
#  3   type       20662 non-null  object
#  4   tags       18065 non-null  object
#  5   doi        20666 non-null  object
# dtypes: object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Preprocessing: Filling missing article language using LLM

# %%
df_clean_articles[df_clean_articles['languages'].isna()]
# Out:
#                                                     title  \
# 616            Medical Malpractice and Black-Box Medicine
# 1114                                Feature Visualization
# 1942    Prescription Drug Monitoring Programs: Examini...
# 3597                                    Mass spectrometry
# 3638     [26] Raster3D: Photorealistic molecular graphics
# ...                                                   ...
# 351285  HLT-FBK: a Complete Temporal Processing System...
# 351286  HCTI at SemEval-2017 Task 1: Use convolutional...
# 351834                Multilingual semantic role labeling
# 351838  International standard for a linguistic annota...
# 365872  Positive effect of hydroxychloroquine on lipid...
#
#                                                  abstract languages  \
# 616                                                  None      None
# 1114                                                 None      None
# 1942                                                 None      None
# 3597                                                 None      None
# 3638    This chapter discusses Raster3D, which is a su...      None
# ...                                                   ...       ...
# 351285                                               None      None
# 351286                                               None      None
# 351834  This paper describes our contribution to the s...      None
# 351838                                               None      None
# 365872                                               None      None
#
#                        type  \
# 616            book-chapter
# 1114        journal-article
# 1942        journal-article
# 3597        journal-article
# 3638           book-chapter
# ...                     ...
# 351285  proceedings-article
# 351286  proceedings-article
# 351834  proceedings-article
# 351838  proceedings-article
# 365872      journal-article
#
#                                                      tags  \
# 616                                                  None
# 1114                          [General Materials Science]
# 1942               [General Medicine, Emergency Medicine]
# 3597    [Biochemistry, Molecular Biology, Structural B...
# 3638                                                 None
# ...                                                   ...
# 351285                                               None
# 351286                                               None
# 351834                                               None
# 351838                                               None
# 365872  [Psychiatry and Mental health, Neuropsychology...
#
#                                                       doi
# 616                             10.1017/9781108147972.027
# 1114                               10.23915/distill.00007
# 1942                        10.5811/westjem.2014.10.24197
# 3597    10.1002/(sici)1097-0134(1998)33:2+<1::aid-prot...
# 3638                        10.1016/s0076-6879(97)77028-9
# ...                                                   ...
# 351285                               10.18653/v1/s15-2135
# 351286                               10.18653/v1/s17-2016
# 351834                            10.3115/1596409.1596416
# 351838                            10.3115/1119226.1119230
# 365872                       10.5152/eurjrheum.2020.20193
#
# [594 rows x 6 columns]

# %%
language_options = ",".join([x[0] for x in list(df_clean_articles['languages'].value_counts().keys())])
language_options
# Out:
# 'en,de,no,da,fr,it,nl,jv,lb,af,zu,la,cy,ca,gl,et,es,fil,sn,ga,fy,sv,pt,el,ceb,yo,el-Latn,ng,ny,co,gd,ru-Latn'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-3.5-turbo", api_key=api_key, temperature=0)

template = """
Return the language of the article by title: {title}. 
""" + f"Available options: {language_options}"

language_prompt = ChatPromptTemplate.from_template(template)

# %%
language_chain = language_prompt | llm | StrOutputParser()

# %%
_t = df_clean_articles[df_clean_articles['languages'].isna()].iloc[0, 0]
_t
# Out:
# 'Medical Malpractice and Black-Box Medicine'

# %%
language_chain.invoke({"title": _t})
# Out:
# 'en'

# %%
df_clean_articles['languages'] = df_clean_articles.progress_apply(
    lambda row: [language_chain.invoke({"title": row['title']})] if pd.isna(row['languages']) else row['languages'], axis=1 #
)
# Out:
#   0%|          | 0/20666 [00:00<?, ?it/s]
# /tmp/ipykernel_165583/4044245384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_articles['languages'] = df_clean_articles.progress_apply(

# %%
df_clean_articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20666 entries, 0 to 372181
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      20666 non-null  object
#  1   abstract   6603 non-null   object
#  2   languages  20666 non-null  object
#  3   type       20662 non-null  object
#  4   tags       18065 non-null  object
#  5   doi        20666 non-null  object
# dtypes: object(6)
# memory usage: 1.1+ MB

# %%
df_clean_articles['languages'].value_counts()
# Out:
# languages
# [en]         20523
# [de]            18
# [no]            11
# [da]            11
# [fr]            10
# [it]            10
# [nl]             7
# [jv]             6
# [af]             6
# [lb]             6
# [zu]             5
# [la]             5
# [ca]             4
# [gu]             4
# [es]             4
# [cy]             4
# [et]             4
# [gl]             4
# [fil]            3
# [pt]             2
# [fy]             2
# [el]             2
# [sn]             2
# [sv]             2
# [ga]             2
# [yo]             1
# [ar]             1
# [ceb]            1
# [el-Latn]        1
# [co]             1
# [ng]             1
# [gd]             1
# [ny]             1
# [ru-Latn]        1
# Name: count, dtype: int64

# %%
df_clean_articles.to_csv("languages_filled.csv")

# %% [markdown]
# ## Preprocessing: Creating tag anthology using LLM

# %%
unique_tags = set(value for sublist in df['tags'] if sublist is not None for value in sublist)

# %%
list(unique_tags)[:20]
# Out:
# ['',
#  'Probability',
#  'Diathermy',
#  'Dextran Sulfate',
#  'Nursing (miscellaneous)',
#  'Anthrax',
#  'Health Care Surveys',
#  'Medical Records',
#  'Verbal Behavior',
#  'Language',
#  'E-mail',
#  'Self Care',
#  'Double-Blind Method',
#  'Adaptation, Psychological',
#  'Multidisciplinary',
#  'Stem Cells',
#  'Mannose-Binding Lectins',
#  'Bone Neoplasms',
#  'Estrogens, Conjugated (USP)',
#  'Molecular Medicine']

# %%
llm = ChatOpenAI(model="gpt-4o", api_key=api_key, temperature=0)

template = """You will be given a set of article tags. 
Your task is to create and return a 3/4-level anthology
to be used to further map the tags.

Article tags: {tags}

Make sure to include all tags into the anthology
Return the anthology as nested python dictionary"""

anthology_prompt = ChatPromptTemplate.from_template(template)

# %%
anthology_chain = anthology_prompt | llm | StrOutputParser()

# %%
tag_anthology = anthology_chain.invoke({"tags": unique_tags})

# %%
with open('anthology.txt', 'w') as f:
    f.write(tag_anthology)

# %% [markdown]
# ## Authors

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
embedding = SentenceTransformerEmbeddings()

# %%
query = """
MATCH (a:author)-[:author]->(d:doi)
RETURN a.given AS given, a.family AS family, collect(d.title) AS titles
"""

# %%
data = graph.run(query).data()

# %%
df = pd.DataFrame(data)

# %%
df_clean_authors = df.dropna(subset=['family'])

# %%
df_clean_authors.shape
# Out:
# (94092, 3)

# %%
def is_not_empty_list(lst):
    return len(lst) > 0

# %%
# clean authors with not articles

# %%
df_clean_authors = df_clean_authors[df_clean_authors['titles'].apply(is_not_empty_list)]

# %%
# sometimes the given name is in the family name, especially for single publication
df_clean_authors[df_clean_authors['given'].isna()]
# Out:
#       given                                             family  \
# 1114   None  The Tobacco Use and Dependence Clinical Practi...
# 1120   None      for the Evidence-Based Medicine Working Group
# 1129   None                              for the CONSORT Group
# 11586  None                          SHARP Collaborative Group
# 22676  None                                            ChatGPT
# 30474  None                                         Madhusudan
# 30960  None                     The Lancet Infectious Diseases
# 31762  None                          The Lancet Digital Health
# 36228  None                     NHLBI Exome Sequencing Project
# 47385  None                                     Prem Ramaswami
# 48737  None                                             Sobral
# 48741  None                                             Harden
# 48742  None                                             Crosby
# 48743  None                                              Davis
# 48744  None                                              Howie
# 48745  None                                          Struthers
# 52856  None                                          Willyanto
# 63990  None                                        Hyosig Kang
# 64047  None                                         Ding Huang
# 64048  None                                           Hong Yan
# 65506  None                                            May Liu
# 65524  None                                   Guang-Zhong Yang
# 65600  None                                         Zhuo Zhang
# 65601  None                                      Feng Shou Yin
# 65602  None                                          Jiang Liu
# 65603  None                                      Wing Kee Wong
# 65604  None                                      Ngan Meng Tan
# 65605  None                                       Beng Hai Lee
# 65606  None                                          Jun Cheng
# 65607  None                                      Tien Yin Wong
# 65911  None                                         Xiong Yang
# 65912  None                                          Liang Lin
# 65913  None                                        Mun Wai Lee
# 65914  None                                      Song-Chun Zhu
# 66115  None                                         Xiao-Yu Fu
# 66198  None                                            Dong Yu
# 66199  None                                            Li Deng
# 66309  None                                           Jia Zeng
# 66310  None                                       Xiao-Yu Zhao
# 66311  None                                       Xiao-Qin Cao
# 66316  None                                       Nguyen Ha Vo
# 66604  None                                             Qin Li
# 66612  None                                      Yuanjie Zheng
# 66938  None                                        Minlong Lin
# 66939  None                                            Ke Tang
# 66940  None                                            Xin Yao
# 66982  None                                         Zhuowen Tu
# 66983  None                                          Xiang Bai
# 66987  None                                         Lixin Duan
# 66989  None                                            Dong Xu
# 70748  None                                             Miklos
# 88077  None                                         Abhilash B
# 89164  None                                  Jennifer Robinson
# 89165  None                                        Paul Milani
# 89192  None                                              Brenu
# 89194  None                                 Marshall-Gradisnik
# 89223  None                                          Parlitsis
# 89224  None                                              Patel
#
#                                                   titles
# 1114   [A Clinical Practice Guideline for Treating To...
# 1120   [Users' Guides to the Medical Literature: XXII...
# 1129   [Use of the CONSORT Statement and Quality of R...
# 11586  [Study of Heart and Renal Protection (SHARP): ...
# 22676  [Open artificial intelligence platforms in nur...
# 30474  [A transient interaction between two phosphore...
# 30960                           [The COVID-19 infodemic]
# 31762                          [ChatGPT: friend or foe?]
# 36228  [Analysis of 6,515 exomes reveals the recent o...
# 47385  [A randomized controlled trial of online sympt...
# 48737  [An appraisal of medical students' reflection-...
# 48741  [Task-based learning: the answer to integratio...
# 48742  [Task-based learning: the answer to integratio...
# 48743  [Task-based learning: the answer to integratio...
# 48744  [Task-based learning: the answer to integratio...
# 48745  [Task-based learning: the answer to integratio...
# 52856  [Protein sequence design by conformational lan...
# 63990  [Robotic assistants aid surgeons during minima...
# 64047  [Interword distance changes represented by sin...
# 64048  [SCS: Signal, Context, and Structure Features ...
# 65506  [Towards integrating task information in skill...
# 65524  [Cooperative in situ microscopic scanning and ...
# 65600  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65601  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65602  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65603  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65604  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65605  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65606  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65607  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65911           [I2T: Image Parsing to Text Description]
# 65912           [I2T: Image Parsing to Text Description]
# 65913           [I2T: Image Parsing to Text Description]
# 65914           [I2T: Image Parsing to Text Description]
# 66115  [Superhuman performance of surgical tasks by r...
# 66198  [Context-Dependent Pre-Trained Deep Neural Net...
# 66199  [Context-Dependent Pre-Trained Deep Neural Net...
# 66309  [SCS: Signal, Context, and Structure Features ...
# 66310  [SCS: Signal, Context, and Structure Features ...
# 66311  [SCS: Signal, Context, and Structure Features ...
# 66316  [Efficient Extraction of Protein-Protein Inter...
# 66604  [Retinopathy Online Challenge: Automatic Detec...
# 66612               [N4ITK: Improved N3 Bias Correction]
# 66938  [Dynamic Sampling Approach to Training Neural ...
# 66939  [Dynamic Sampling Approach to Training Neural ...
# 66940  [Dynamic Sampling Approach to Training Neural ...
# 66982  [Auto-Context and Its Application to High-Leve...
# 66983  [Auto-Context and Its Application to High-Leve...
# 66987         [Domain Transfer Multiple Kernel Learning]
# 66989         [Domain Transfer Multiple Kernel Learning]
# 70748  [Comparative Genomics of the Eukaryotes, The G...
# 88077  [Comparison of visual acuity measured by ETDRS...
# 89164  [Role of colesevelam in managing heterozygous ...
# 89165  [Role of colesevelam in managing heterozygous ...
# 89192  [The prevalence of chronic fatigue syndrome/ m...
# 89194  [The prevalence of chronic fatigue syndrome/ m...
# 89223  [Comparison of ultra-widefield fluorescein ang...
# 89224  [Comparison of ultra-widefield fluorescein ang...

# %%
def word_count(text):
    return len(text.split())

# %%
# remove coorporations from authors
df_clean_authors = df_clean_authors[df_clean_authors['family'].apply(word_count) < 3]

# %%
df_clean_authors[df_clean_authors['given'].isna()].shape
# Out:
# (44, 3)

# %%
df_clean_authors[df_clean_authors['given'].isna()]
# Out:
#       given              family  \
# 22676  None             ChatGPT
# 30474  None          Madhusudan
# 47385  None      Prem Ramaswami
# 48737  None              Sobral
# 48741  None              Harden
# 48742  None              Crosby
# 48743  None               Davis
# 48744  None               Howie
# 48745  None           Struthers
# 52856  None           Willyanto
# 63990  None         Hyosig Kang
# 64047  None          Ding Huang
# 64048  None            Hong Yan
# 65506  None             May Liu
# 65524  None    Guang-Zhong Yang
# 65600  None          Zhuo Zhang
# 65602  None           Jiang Liu
# 65606  None           Jun Cheng
# 65911  None          Xiong Yang
# 65912  None           Liang Lin
# 65914  None       Song-Chun Zhu
# 66115  None          Xiao-Yu Fu
# 66198  None             Dong Yu
# 66199  None             Li Deng
# 66309  None            Jia Zeng
# 66310  None        Xiao-Yu Zhao
# 66311  None        Xiao-Qin Cao
# 66604  None              Qin Li
# 66612  None       Yuanjie Zheng
# 66938  None         Minlong Lin
# 66939  None             Ke Tang
# 66940  None             Xin Yao
# 66982  None          Zhuowen Tu
# 66983  None           Xiang Bai
# 66987  None          Lixin Duan
# 66989  None             Dong Xu
# 70748  None              Miklos
# 88077  None          Abhilash B
# 89164  None   Jennifer Robinson
# 89165  None         Paul Milani
# 89192  None               Brenu
# 89194  None  Marshall-Gradisnik
# 89223  None           Parlitsis
# 89224  None               Patel
#
#                                                   titles
# 22676  [Open artificial intelligence platforms in nur...
# 30474  [A transient interaction between two phosphore...
# 47385  [A randomized controlled trial of online sympt...
# 48737  [An appraisal of medical students' reflection-...
# 48741  [Task-based learning: the answer to integratio...
# 48742  [Task-based learning: the answer to integratio...
# 48743  [Task-based learning: the answer to integratio...
# 48744  [Task-based learning: the answer to integratio...
# 48745  [Task-based learning: the answer to integratio...
# 52856  [Protein sequence design by conformational lan...
# 63990  [Robotic assistants aid surgeons during minima...
# 64047  [Interword distance changes represented by sin...
# 64048  [SCS: Signal, Context, and Structure Features ...
# 65506  [Towards integrating task information in skill...
# 65524  [Cooperative in situ microscopic scanning and ...
# 65600  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65602  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65606  [ORIGA<sup>-light</sup>: An online retinal fun...
# 65911           [I2T: Image Parsing to Text Description]
# 65912           [I2T: Image Parsing to Text Description]
# 65914           [I2T: Image Parsing to Text Description]
# 66115  [Superhuman performance of surgical tasks by r...
# 66198  [Context-Dependent Pre-Trained Deep Neural Net...
# 66199  [Context-Dependent Pre-Trained Deep Neural Net...
# 66309  [SCS: Signal, Context, and Structure Features ...
# 66310  [SCS: Signal, Context, and Structure Features ...
# 66311  [SCS: Signal, Context, and Structure Features ...
# 66604  [Retinopathy Online Challenge: Automatic Detec...
# 66612               [N4ITK: Improved N3 Bias Correction]
# 66938  [Dynamic Sampling Approach to Training Neural ...
# 66939  [Dynamic Sampling Approach to Training Neural ...
# 66940  [Dynamic Sampling Approach to Training Neural ...
# 66982  [Auto-Context and Its Application to High-Leve...
# 66983  [Auto-Context and Its Application to High-Leve...
# 66987         [Domain Transfer Multiple Kernel Learning]
# 66989         [Domain Transfer Multiple Kernel Learning]
# 70748  [Comparative Genomics of the Eukaryotes, The G...
# 88077  [Comparison of visual acuity measured by ETDRS...
# 89164  [Role of colesevelam in managing heterozygous ...
# 89165  [Role of colesevelam in managing heterozygous ...
# 89192  [The prevalence of chronic fatigue syndrome/ m...
# 89194  [The prevalence of chronic fatigue syndrome/ m...
# 89223  [Comparison of ultra-widefield fluorescein ang...
# 89224  [Comparison of ultra-widefield fluorescein ang...

# %%
given_names = df_clean_authors[df_clean_authors['given'].isna()]['family'].apply(lambda x: x.split(' ')[0] if len(x.split(' ')) == 2 else "_")

# %%
given_names.values
# Out:
# array(['_', '_', 'Prem', '_', '_', '_', '_', '_', '_', '_', 'Hyosig',
#        'Ding', 'Hong', 'May', 'Guang-Zhong', 'Zhuo', 'Jiang', 'Jun',
#        'Xiong', 'Liang', 'Song-Chun', 'Xiao-Yu', 'Dong', 'Li', 'Jia',
#        'Xiao-Yu', 'Xiao-Qin', 'Qin', 'Yuanjie', 'Minlong', 'Ke', 'Xin',
#        'Zhuowen', 'Xiang', 'Lixin', 'Dong', '_', 'Abhilash', 'Jennifer',
#        'Paul', '_', '_', '_', '_'], dtype=object)

# %%
df_clean_authors.loc[given_names.index, 'given'] = given_names.values

# %%
# in some cases there is extra punctuation

# %%
df_clean_authors[(df_clean_authors['family'] == "Johnson") & (df_clean_authors['given'].str[0] == "J")].sort_values(['given'])
# Out:
#             given   family                                             titles
# 34480           J  Johnson      [A prognostic index in primary breast cancer]
# 10863          J.  Johnson  [Crystallographic structure of an RNA helix: [...
# 59689       James  Johnson  [The MEME Suite, Diagnostic accuracy of X-ray ...
# 85208     Jason M  Johnson  [Mapping the Genetic Architecture of Gene Expr...
# 87440        Jean  Johnson  [Creating Opportunities for Parent Empowerment...
# 69566     Jeffery  Johnson                 [The Sequence of the Human Genome]
# 73143   Jeffrey A  Johnson  [A meta-analysis of the association between ad...
# 9456   Jeffrey A.  Johnson  [Understanding the complex associations betwee...
# 30094   Jeffrey C  Johnson  [Beliefs about and responses to childhood ear ...
# 74138      Jill R  Johnson  [Effectiveness of screening colonoscopy in red...
# 33670     John E.  Johnson  [Atomic structure of the 75 MDa extremophile\n...
# 37467         Jon  Johnson  [The UK10K project identifies rare variants in...
# 6652    Joseph O.  Johnson     [Image Analysis of the Tumor Microenvironment]
# 7187    Judith P.  Johnson  [Cell adhesion molecules of the immunoglobulin...
# 9553       Justin  Johnson  [CLEVR: A Diagnostic Dataset for Compositional...
# 83497   Justin M.  Johnson     [Survey on deep learning with class imbalance]

# %%
df_clean_authors['given'] = df_clean_authors['given'].apply(lambda x: x.replace(".", "") if x else x)

# %%
df_clean_authors[(df_clean_authors['family'] == "Johnson") & (df_clean_authors['given'].str[0] == "J")].sort_values(['given'])
# Out:
#            given   family                                             titles
# 10863          J  Johnson  [Crystallographic structure of an RNA helix: [...
# 34480          J  Johnson      [A prognostic index in primary breast cancer]
# 59689      James  Johnson  [The MEME Suite, Diagnostic accuracy of X-ray ...
# 85208    Jason M  Johnson  [Mapping the Genetic Architecture of Gene Expr...
# 87440       Jean  Johnson  [Creating Opportunities for Parent Empowerment...
# 69566    Jeffery  Johnson                 [The Sequence of the Human Genome]
# 9456   Jeffrey A  Johnson  [Understanding the complex associations betwee...
# 73143  Jeffrey A  Johnson  [A meta-analysis of the association between ad...
# 30094  Jeffrey C  Johnson  [Beliefs about and responses to childhood ear ...
# 74138     Jill R  Johnson  [Effectiveness of screening colonoscopy in red...
# 33670     John E  Johnson  [Atomic structure of the 75 MDa extremophile\n...
# 37467        Jon  Johnson  [The UK10K project identifies rare variants in...
# 6652    Joseph O  Johnson     [Image Analysis of the Tumor Microenvironment]
# 7187    Judith P  Johnson  [Cell adhesion molecules of the immunoglobulin...
# 9553      Justin  Johnson  [CLEVR: A Diagnostic Dataset for Compositional...
# 83497   Justin M  Johnson     [Survey on deep learning with class imbalance]

# %%
one_letter_name = df_clean_authors[df_clean_authors['given'].apply(lambda x: len(x.replace(".","")) if x else 0) == 1]

# %%
def concatenate_lists(series):
    return series.sum()

# %%
# Group by 'given' and 'family' columns and concatenate lists in grouped rows
grouped_df = df_clean_authors.groupby(['given', 'family']).agg({
    'titles': concatenate_lists,
}).reset_index()

# %%
grouped_df.shape
# Out:
# (91429, 3)

# %%
embedding.embed_query("; ".join(grouped_df.iloc[0,-1]))[:10]
# Out:
# [0.039591751992702484,
#  -0.07843189686536789,
#  0.026333099231123924,
#  0.03865569829940796,
#  0.004176840651780367,
#  0.022404426708817482,
#  -0.0013168402947485447,
#  0.008029144257307053,
#  -0.003868338419124484,
#  -0.015063636936247349]

# %%
embeddings = grouped_df['titles'].progress_apply(lambda x: embedding.embed_query("; ".join(x)))
grouped_df['embeddings'] = embeddings
# Out:
#   0%|          | 0/91429 [00:00<?, ?it/s]

# %%
grouped_df.to_csv("embedding_authors_3.csv")

# %%
grouped_df.head()
# Out:
#           given     family                                             titles  \
# 0  (The Late) B   Tilander  [Crystal structure of human erythrocyte carbon...
# 1             >     Kleeff  [Insulin-Like Growth Factor Signaling as a The...
# 2     ??eslovas  Venclovas  [Assessment of progress over the CASP experime...
# 3      ?eslovas  Venclovas  [Processing and analysis of CASP3 protein stru...
# 4             A   ANDERSON  [Cancer patients' concerns regarding access to...
#
#                                           embeddings
# 0  [0.039591751992702484, -0.07843189686536789, 0...
# 1  [0.05088701471686363, -0.012295341119170189, 0...
# 2  [-0.046196773648262024, -0.009418211877346039,...
# 3  [-0.037653807550668716, -0.04398495331406593, ...
# 4  [0.05151272565126419, 0.06267254054546356, -0....

# %%
from sklearn.metrics.pairwise import cosine_similarity
def process_single_letter_names(df, similarity_threshold=0.75):
    # Group by family name
    grouped = df.groupby('family')

    # Prepare a list to store the final results
    results = []

    for family_name, group in progress_tqdm(grouped):
        # Find single-letter given names
        single_letter_names = group[group['given'].str.len() == 1]

        # Process each single-letter given name
        for _, single_letter_row in single_letter_names.iterrows():
            single_letter_embedding = single_letter_row['embeddings']
            single_letter_given = single_letter_row['given']

            # Compare with other given names in the same family
            for _, row in group.iterrows():
                if row['given'] != single_letter_given and (row['given'][0] == single_letter_given or single_letter_given == "_"):
                    other_embedding = row['embeddings']
                    similarity = cosine_similarity(
                        [single_letter_embedding], [other_embedding]
                    )[0][0]
                    if similarity > similarity_threshold:
                        results.append({
                            'given': single_letter_given,
                            'family': family_name,
                            'matched_given': row['given'],
                            'similarity': similarity
                        })

    return pd.DataFrame(results)

# %%
candidates_df = process_single_letter_names(grouped_df, similarity_threshold=0.7)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 45765/45765 [01:08<00:00, 672.57it/s]

# %%
candidates_df['matched_given'].head(50)
# Out:
# 0      Gonçalo R
# 1           Linn
# 2          Keith
# 3           Faiz
# 4           Kaat
# 5          Kevin
# 6            S J
# 7      Stephen J
# 8         Younes
# 9          Joana
# 10     Stephen F
# 11        Sophia
# 12       Richard
# 13      Fumihito
# 14       Susan G
# 15        Michal
# 16        Alvaro
# 17         Helen
# 18         Elena
# 19         Chris
# 20       Gillian
# 21         Marin
# 22         Helen
# 23       Helen M
# 24     Christian
# 25        Andrew
# 26       Agatino
# 27       Jessica
# 28        Hugues
# 29       Roberto
# 30           Tom
# 31      Catalina
# 32       Valérie
# 33      Adrian P
# 34     Charlotte
# 35       Andreas
# 36         Nadia
# 37      Miloslav
# 38        Thomas
# 39         Sally
# 40     Florian P
# 41          Sean
# 42       Jessica
# 43        Andrew
# 44       Monique
# 45        Durado
# 46          Dirk
# 47     Matthew J
# 48          Timo
# 49    Philippe M
# Name: matched_given, dtype: object

# %%
candidates_df.to_csv("candidates.csv")

# %% [markdown]
# ## Applying Preprocessing

# %%
# Connect to the Neo4j database
graph = Graph("bolt://localhost:7687", name = "smallstc", auth=("neo4j", "Stargate90"))

# %%
df_clean_articles = pd.read_csv("languages_filled.csv", index_col=[0])

# %%
df_clean_articles
# Out:
#                                                     title  \
# 0       Information Overload and Missed Test Results i...
# 1       Ethical Dimensions of Using Artificial Intelli...
# 2        Should Watson Be Consulted for a Second Opinion?
# 3       How Should Clinicians Communicate With Patient...
# 4       Are Current Tort Liability Doctrines Adequate ...
# ...                                                   ...
# 367240  Socioeconomic deprivation scores as predictors...
# 367277                                      Level or not?
# 368135  Understanding and using sensitivity, specifici...
# 372050  Cervical Pessary for Preventing Preterm Birth ...
# 372181  Factors associated with attendance at primary ...
#
#                                                  abstract languages  \
# 0                                                     NaN    ['en']
# 1                                                     NaN    ['en']
# 2                                                     NaN    ['en']
# 3                                                     NaN    ['en']
# 4                                                     NaN    ['en']
# ...                                                   ...       ...
# 367240  Background\nA previous study found that variab...    ['en']
# 367277                                                NaN    ['en']
# 368135                                                NaN    ['en']
# 372050                                                NaN    ['en']
# 372181                                                NaN    ['en']
#
#                    type                                               tags  \
# 0       journal-article                              ['Internal Medicine']
# 1       journal-article  ['Health (social science)', 'Health Policy', '...
# 2       journal-article  ['Health (social science)', 'Health Policy', '...
# 3       journal-article  ['Health (social science)', 'Health Policy', '...
# 4       journal-article  ['Health (social science)', 'Health Policy', '...
# ...                 ...                                                ...
# 367240  journal-article                                ['Family Practice']
# 367277           report                                                NaN
# 368135  journal-article                                  ['Ophthalmology']
# 372050  journal-article  ['Radiology, Nuclear Medicine and imaging', 'R...
# 372181  journal-article                               ['General Medicine']
#
#                                   doi
# 0       10.1001/2013.jamainternmed.61
# 1         10.1001/amajethics.2019.121
# 2         10.1001/amajethics.2019.131
# 3         10.1001/amajethics.2019.138
# 4         10.1001/amajethics.2019.160
# ...                               ...
# 367240          10.3399/bjgp19x704549
# 367277          10.37829/hf-2020-rc13
# 368135        10.4103/0301-4738.41424
# 372050         10.7863/ultra.16.08054
# 372181         10.9778/cmajo.20180069
#
# [20666 rows x 6 columns]

# %%
candidates_df = pd.read_csv("candidates.csv", index_col=[0])

# %%
candidates_df
# Out:
#     given        family matched_given  similarity
# 0       G      Abecasis     Gonçalo R    0.823202
# 1       L       Abraham          Linn    0.800957
# 2       K        Abrams         Keith    0.799398
# 3       F    Ahmad Khan          Faiz    0.769182
# 4       K       Alaerts          Kaat    0.867004
# ..    ...           ...           ...         ...
# 452     C       Zywietz     Christoph    0.714291
# 453     M       de Boer        Maaike    0.868919
# 454     M      de Jonge       Maretha    0.782835
# 455     M   de Mathelin            MF    0.771620
# 456     B  van Ginneken          Bram    0.878928
#
# [457 rows x 4 columns]

# %%
query = """
MATCH (a:doi)
OPTIONAL MATCH (a)-[:reference]->(ref:doi)
RETURN a.title AS title, 
       a.abstract AS abstract, 
       a.languages AS languages, 
       a.type AS type, 
       a.tags AS tags,
       a.updated_at AS updated_at, 
       a.container_title AS container_title, 
       a.is_content_present AS is_content_present,
       a.name AS doi, 
       a.issued_at AS issued_at,
       collect(ref.name) AS references
"""

# %%
# Execute the query
data = graph.run(query).data()

# %%
# Convert the result to a DataFrame
doi_df = pd.DataFrame(data)

# %%
query = """
MATCH (a:author)-[:author]->(d:doi)
RETURN a.given AS given, a.family AS family, a.orcid as orcid, d.name as doi, a.id_hash as id_hash
"""

# %%
# Execute the query
data = graph.run(query).data()

# %%
author_df = pd.DataFrame(data)

# %%
result_df = pd.merge(author_df, doi_df, on="doi")

# %%
result_df.drop(['languages'], axis=1, inplace=True)

# %%
result_df = result_df.dropna(subset=['family'])

# %%
result_df['given'] = result_df['given'].apply(lambda x: x.replace(".", "") if (x and len(x) >= 3) else x)

# %%
result_df = pd.merge(result_df, df_clean_articles[['doi', 'languages']], on="doi")

# %%
result_df = pd.merge(result_df, candidates_df[['given','family','matched_given']], on=['given','family'], how="left")

# %%
def is_nan(value):
    return pd.isna(value)

# %%
result_df["given"] = result_df.apply(lambda x: x['matched_given'] if not is_nan(x['matched_given']) else x['given'], axis=1)

# %%
result_df.drop("matched_given", axis=1, inplace=True)

# %%
result_df.head()
# Out:
#         given        family orcid                              doi  \
# 0     Hardeep         Singh  None    10.1001/2013.jamainternmed.61
# 1     Hardeep         Singh  None  10.1001/jamainternmed.2013.2777
# 2  Christiane  Spitzmueller  None    10.1001/2013.jamainternmed.61
# 3     Nancy J      Petersen  None    10.1001/2013.jamainternmed.61
# 4      Mona K       Sawhney  None    10.1001/2013.jamainternmed.61
#
#                                              id_hash  \
# 0  b985366129f0c2a7e0ba05e5de448161963c124b684400...
# 1  b985366129f0c2a7e0ba05e5de448161963c124b684400...
# 2  1028cd415ed3557f212fb355330f99ff25253215b48e35...
# 3  160a8b32b0df7105d254186517dfb2aab0c1c3418744a4...
# 4  addfa31adbe848ff77d9f120cc42ae3cef02e4574ff5b9...
#
#                                                title abstract  \
# 0  Information Overload and Missed Test Results i...     None
# 1  Types and Origins of Diagnostic Errors in Prim...     None
# 2  Information Overload and Missed Test Results i...     None
# 3  Information Overload and Missed Test Results i...     None
# 4  Information Overload and Missed Test Results i...     None
#
#               type                 tags    updated_at         container_title  \
# 0  journal-article  [Internal Medicine]  1.695848e+09  JAMA Internal Medicine
# 1  journal-article  [Internal Medicine]  1.695840e+09  JAMA Internal Medicine
# 2  journal-article  [Internal Medicine]  1.695848e+09  JAMA Internal Medicine
# 3  journal-article  [Internal Medicine]  1.695848e+09  JAMA Internal Medicine
# 4  journal-article  [Internal Medicine]  1.695848e+09  JAMA Internal Medicine
#
#   is_content_present     issued_at references languages
# 0              False  1.366589e+09         []    ['en']
# 1              False  1.364170e+09         []    ['en']
# 2              False  1.366589e+09         []    ['en']
# 3              False  1.366589e+09         []    ['en']
# 4              False  1.366589e+09         []    ['en']

# %%
result_df.columns
# Out:
# Index(['given', 'family', 'orcid', 'doi', 'id_hash', 'title', 'abstract',
#        'type', 'tags', 'updated_at', 'container_title', 'is_content_present',
#        'issued_at', 'references', 'languages'],
#       dtype='object')

# %%
result_df.to_csv("result_df.csv")

# %% [markdown]
# ## Upload to neo4j

# %%
from py2neo import Graph
system_graph = Graph("bolt://localhost:7687", auth=("neo4j", "Stargate90"), name="system")

# Create the new database "updated graph" if it doesn't exist
try:
    system_graph.run("CREATE DATABASE `smallstc-upd`")
except Exception as e:
    print(e)
# Out:
# [Database.ExistingDatabaseFound] Failed to create the specified database 'smallstc-upd': Database name or alias already exists.

# %%
graph = Graph("bolt://localhost:7687", auth=("neo4j", "Stargate90"), name="smallstc-upd")
try:
    graph.run("MATCH (n) DETACH DELETE n")
except Exception as e:
    print(e)

# %%
def create_author_nodes(row):
    author = Node("author", given=row['given'], family=row['family'], orcid=row['orcid'], id_hash=row["id_hash"])
    return author

def create_article_nodes(row):
    article = Node("article", doi=row['doi'], title=row['title'], abstract=row['abstract'], 
                   type=row['type'], tags=row['tags'], updated_at=row['updated_at'], 
                   container_title=row['container_title'], is_content_present=row['is_content_present'], 
                   issued_at=row['issued_at'], languages=row['languages'])
    return article

# %%
from py2neo import Node, Relationship

for idx, row in progress_tqdm(result_df.iterrows()):
    author = create_author_nodes(row)
    article = create_article_nodes(row)

    # Merge nodes to avoid duplicates
    graph.merge(author, "author", "id_hash")
    graph.merge(article, "article", "doi")

    # Create relationships between author and article
    written_by = Relationship(article, "AUTHORED_BY", author)
    graph.create(written_by)

    # Optionally: Add tags as nodes and create relationships to articles
    if row['tags']:
        tags = row['tags']
        for tag in tags:
            tag_node = Node("tag", name=tag.strip())
            graph.merge(tag_node, "tag", "name")
            tagged_with = Relationship(article, "TAGGED_WITH", tag_node)
            graph.create(tagged_with)
# Out:
# 137905it [3:42:44, 10.32it/s]

# %%
'''for idx, row in progress_tqdm(result_df[['doi', 'references']].explode('references').dropna().iterrows()):
    ref_article = graph.nodes.match("article", doi=row['references']).first()
    doi_article = graph.nodes.match("article", doi=row['doi']).first()
    if ref_article and doi_article:
        graph.create(Relationship(doi_article, "REFERENCES", ref_article))
'''
        
        
        
def create_relationships_in_batches(df, batch_size=100):
    query_template = """
    UNWIND $rows AS row
    MATCH (a:article {doi: row.doi}), (r:article {doi: row.references})
    MERGE (a)-[:REFERENCES]->(r)
    """
    total_rows = len(df)
    for start in progress_tqdm(range(0, total_rows, batch_size)):
        end = min(start + batch_size, total_rows)
        batch = df.iloc[start:end].to_dict('records')
        graph.run(query_template, rows=batch)

df = result_df[['doi', 'references']].explode('references').dropna()        
        
# Call the function with the flattened DataFrame
create_relationships_in_batches(df, batch_size=100)
# Out:
#  12%|████████████▎                                                                                           | 7109/59896 [7:05:50<52:42:02,  3.59s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 25
#      22 df = result_df[['doi', 'references']].explode('references').dropna()
#      24 # Call the function with the flattened DataFrame
# ---> 25 create_relationships_in_batches(df, batch_size=100)
#
# Cell In[66], line 20, in create_relationships_in_batches(df, batch_size)
#      18 end = min(start + batch_size, total_rows)
#      19 batch = df.iloc[start:end].to_dict('records')
# ---> 20 graph.run(query_template, rows=batch)
#
# File ~/.local/lib/python3.10/site-packages/py2neo/database.py:405, in Graph.run(self, cypher, parameters, **kwparameters)
#     395 def run(self, cypher, parameters=None, **kwparameters):
#     396     """ Run a single read/write query within an auto-commit
#     397     :class:`~py2neo.Transaction`.
#     398
#    (...)
#     403     :return:
#     404     """
# --> 405     return self.auto().run(cypher, parameters, **kwparameters)
#
# File ~/.local/lib/python3.10/site-packages/py2neo/database.py:992, in Transaction.run(self, cypher, parameters, **kwparameters)
#     988     else:
#     989         result = self._connector.auto_run(cypher, parameters,
#     990                                           graph_name=self.graph.name,
#     991                                           readonly=self.readonly)
# --> 992     self._connector.pull(result, -1)
#     993     return Cursor(result, hydrant)
#     994 finally:
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/__init__.py:1434, in Connector.pull(self, result, n)
#    1432 cx = self._reacquire(result.transaction)
#    1433 try:
# -> 1434     cx.pull(result, n=n)
#    1435 except (ConnectionUnavailable, ConnectionBroken):
#    1436     self.prune(cx.profile)
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:995, in Bolt4x0.pull(self, result, n, capacity)
#     993 result.append(response, final=(n == -1))
#     994 try:
# --> 995     self._sync(response)
#     996 except BrokenWireError as error:
#     997     result.transaction.mark_broken()
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:799, in Bolt1._sync(self, *responses)
#     797 self.send()
#     798 for response in responses:
# --> 799     self._wait(response)
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:794, in Bolt1._wait(self, response)
#     787 """ Read all incoming responses up to and including a
#     788 particular response.
#     789
#     790 This method calls fetch, but does not raise an exception on
#     791 FAILURE.
#     792 """
#     793 while not response.full() and not response.done():
# --> 794     self._fetch()
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:769, in Bolt1._fetch(self)
#     760 def _fetch(self):
#     761     """ Fetch and process the next incoming message.
#     762
#     763     This method does not raise an exception on receipt of a
#    (...)
#     767     failed state into an exception.
#     768     """
# --> 769     tag, fields = self.read_message()
#     770     if tag == 0x70:
#     771         self._responses.popleft().set_success(**fields[0])
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:696, in Bolt1.read_message(self)
#     695 def read_message(self):
# --> 696     tag, fields = self._reader.read_message()
#     697     if tag == 0x71:
#     698         # If a RECORD is received, check for more records
#     699         # in the buffer immediately following, and log and
#     700         # add them all at the same time
#     701         while self._reader.peek_message() == 0x71:
#
# File ~/.local/lib/python3.10/site-packages/py2neo/client/bolt.py:156, in BoltMessageReader.read_message(self)
#     154 while True:
#     155     try:
# --> 156         hi, lo = self.wire.read(2)
#     157     except WireError as error:
#     158         raise_from(ConnectionBroken("Failed to read message"), error)
#
# File ~/.local/lib/python3.10/site-packages/py2neo/wiring.py:117, in Wire.read(self, n)
#     115 requested = max(required, 16384)
#     116 try:
# --> 117     received = self.__socket.recv(requested)
#     118 except (IOError, OSError):
#     119     self.__mark_broken("Wire broken")
#
# KeyboardInterrupt:

# %%
import json
with open("anthology.json", 'r') as f:
    tag_anthology = json.load(f)

# %%
# Recursive function to create nodes and relationships in Neo4j
def create_relationships(parent_name, children):
    if isinstance(children, dict):
        for child_name, grand_children in children.items():
            parent_node = Node("tag", name=parent_name)
            child_node = Node("tag", name=child_name)
            graph.merge(parent_node, "tag", "name")
            graph.merge(child_node, "tag", "name")
            related_to = Relationship(child_node, "RELATED_TO", parent_node)
            graph.merge(related_to)
            create_relationships(child_name, grand_children)
    elif isinstance(children, list):
        parent_node = Node("tag", name=parent_name)
        graph.merge(parent_node, "tag", "name")
        for child_name in children:
            child_node = Node("tag", name=child_name)
            graph.merge(child_node, "tag", "name")
            related_to = Relationship(child_node, "RELATED_TO", parent_node)
            graph.merge(related_to)

# %%
for root_tag, sub_tags in progress_tqdm(tag_anthology.items()):
    create_relationships(root_tag, sub_tags)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:04<00:00,  1.42it/s]

# %%
df
# Out:
#                                  doi                          references
# 5       10.1016/j.amjmed.2011.07.029                  10.1200/jop.091098
# 5       10.1016/j.amjmed.2011.07.029        10.1001/archinte.163.21.2625
# 5       10.1016/j.amjmed.2011.07.029    10.1046/j.1365-2710.2002.00434.x
# 5       10.1016/j.amjmed.2011.07.029  10.1097/01.jac.0000290402.89284.a9
# 5       10.1016/j.amjmed.2011.07.029                 10.1197/jamia.m3200
# ...                              ...                                 ...
# 137886        10.7863/ultra.34.2.225        10.1097/sla.0b013e318204a892
# 137886        10.7863/ultra.34.2.225       10.1016/s0002-9610(03)00042-4
# 137886        10.7863/ultra.34.2.225             10.1186/1471-2407-9-335
# 137886        10.7863/ultra.34.2.225          10.1016/j.acra.2008.01.010
# 137886        10.7863/ultra.34.2.225       10.1016/s1076-6332(97)80154-7
#
# [5989592 rows x 2 columns]

# %% [markdown]
# ## Querying

# %%
#check the examples

# %%
from langchain.chains import GraphCypherQAChain
from langchain_community.graphs import Neo4jGraph
from langchain_openai import ChatOpenAI

graph = Neo4jGraph(url="bolt://localhost:7687", username="neo4j", password="Stargate90", database="smallstc-upd")

# %%
from langchain_core.prompts.prompt import PromptTemplate

CYPHER_GENERATION_TEMPLATE = """Task:Generate Cypher statement to query a graph database.
Instructions:
Use only the provided relationship types and properties in the schema.
Do not use any other relationship types or properties that are not provided.
Schema:
{schema}
Note: Do not include any explanations or apologies in your responses.
Do not respond to any questions that might ask anything else than for you to construct a Cypher statement.
Do not include any text except the generated Cypher statement.
Examples: Here are a few examples of generated Cypher statements for particular questions:
# List the titles of articles written by John Doe.
MATCH (a:author {given: "John", family: "Doe"})<-[:AUTHORED_BY]-(art:article)
RETURN art.title

# Find all articles that reference the article with DOI '10.1234/abc123'.
MATCH (a:article {doi: "10.1234/abc123"})<-[:REFERENCES]-(referenced_by:article)
RETURN referenced_by.doi, referenced_by.title

# Get the authors, titles, and citation counts of the most cited articles tagged with 'Breast Neoplasms'.
MATCH (t:tag {name: "Breast Neoplasms"})-[:RELATED_TO*0..]->(subTag:tag)
MATCH (a:article)-[:TAGGED_WITH]->(subTag)
OPTIONAL MATCH (a)<-[:REFERENCES]-(citingArticle:article)
OPTIONAL MATCH (a)-[:AUTHORED_BY]->(auth:author)
RETURN a.title, count(citingArticle) AS citationCount, collect(DISTINCT auth.given + " " + auth.family) AS authors
ORDER BY citationCount DESC
LIMIT 10


The question is:
{question}"""

CYPHER_GENERATION_PROMPT = PromptTemplate(
    input_variables=["schema", "question"], template=CYPHER_GENERATION_TEMPLATE
)

chain = GraphCypherQAChain.from_llm(
    ChatOpenAI(model="gpt-4o", api_key=api_key, temperature=0), graph=graph, verbose=True, validate_cypher=True
)

# %%
chain.run("How many articles reference doi: 10.1016/s0002-9394(02)01522-2?")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (a:article)-[:REFERENCES]->(b:article {doi: "10.1016/s0002-9394(02)01522-2"})
# RETURN count(a)
#
# Full Context:
# [{'count(a)': 14}]
#
# > Finished chain.
# '14 articles reference doi: 10.1016/s0002-9394(02)01522-2.'

# %%
chain.run("Who are the top coauthors of Nilsson Matthew?")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (a:author {given: "Matthew", family: "Nilsson"})<-[:AUTHORED_BY]-(art:article)-[:AUTHORED_BY]->(coauthor:author)
# RETURN coauthor.given, coauthor.family, COUNT(*) AS collaborations
# ORDER BY collaborations DESC
# LIMIT 5
#
# Full Context:
# [{'coauthor.given': 'Susan D', 'coauthor.family': 'Block', 'collaborations': 2}, {'coauthor.given': 'Jennifer W', 'coauthor.family': 'Mack', 'collaborations': 2}, {'coauthor.given': 'Holly G', 'coauthor.family': 'Prigerson', 'collaborations': 2}, {'coauthor.given': 'Elizabeth', 'coauthor.family': 'Trice', 'collaborations': 2}, {'coauthor.given': 'Alexi', 'coauthor.family': 'Wright', 'collaborations': 1}]
#
# > Finished chain.
# 'Susan D. Block, Jennifer W. Mack, Holly G. Prigerson, and Elizabeth Trice are the top coauthors of Nilsson Matthew.'

# %%
chain.run("What are the fields of study of Liu Yun?")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (a:author {family: "Liu", given: "Yun"})-[:AUTHORED_BY]-(art:article)-[:TAGGED_WITH]->(t:tag)
# RETURN DISTINCT t.name AS fields_of_study
#
# Full Context:
# [{'fields_of_study': 'General Medicine'}, {'fields_of_study': 'Ophthalmology'}, {'fields_of_study': 'Anatomy'}, {'fields_of_study': 'Surgery'}, {'fields_of_study': 'Pathology and Forensic Medicine'}, {'fields_of_study': 'Multidisciplinary'}, {'fields_of_study': 'Medical Laboratory Technology'}, {'fields_of_study': 'Radiological and Ultrasound Technology'}, {'fields_of_study': 'Radiology, Nuclear Medicine and imaging'}, {'fields_of_study': 'Computer Vision and Pattern Recognition'}]
#
# > Finished chain.
# 'General Medicine, Ophthalmology, Anatomy, Surgery, Pathology and Forensic Medicine, Multidisciplinary, Medical Laboratory Technology, Radiological and Ultrasound Technology, Radiology, Nuclear Medicine and imaging, Computer Vision and Pattern Recognition.'

# %%
# Possible todo next: compare coauthors, but that's outside of the milestone

# %%
# Possible todo next: Aldington	Stephen J == Aldington	S J == Aldington	S , but that's outside of the milestone
